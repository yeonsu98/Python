# %% [markdown]
# 공부 시간, 과외 시간과 성적 사이의 관계는 좌표로 나타낼 때 형태가 직선으로 해결되는 선형 회귀를 사용하기에 적합했었다.
# 공부 시간에 따른 점수가 아닌 합격 여부로 발표되는 시험이 있을 경우 직선으로 해결하기에는 적합하지 못한 문제가 발생된다.
# 이럴때 사용하는 로지스틱 회귀는 참과 거짓 중에 하나를 내놓는 과정으로 참과 거짓을 구분한 'S'자를 눕혀놓은 형태의 선을 그어주는 작업이다.

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From d:\python36\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from IPython.display import Image
Image('./sigmoid.png', width=800)

# %% [markdown]
# 참조
# http://taewan.kim/post/sigmoid_diff/
# https://devlog.jwgo.kr/2018/04/16/sigmoid-graph-according-to-slope-change/

# %%
# 공부 시간(x), 합격 여부(y) => [공부 시간, 합격 여부]
data = [[2, 0], [4, 0], [6, 0], [8, 1], [10, 1], [12, 1], [14, 1]]
xData = [i[0] for i in data] # 공부 시간
yData = [i[1] for i in data] # 합격 여부

# %%
# 기울기(a)와 y절편(b) 값을 랜덤한 값으로 정한다.
a = tf.Variable(tf.random_normal([1], dtype=tf.float64))
b = tf.Variable(tf.random_normal([1], dtype=tf.float64))
sess = tf.Session()
sess.run(tf.global_variables_initializer())
print('a: {}, b: {}'.format(sess.run(a), sess.run(b)))
# Out:
# a: [0.53997497], b: [-0.47972266]

# %% [markdown]
# 시그모이드 방정식

# %%
# np.e : 넘파이에서 지수 값(2.718281828459045)을 의미하는 상수
# print(np.e)
y = 1 / (1 + np.e ** -(a * xData + b))

# %% [markdown]
# 시그모이드 방정식의 오차를 계산하는 함수를 만든다.
# 시그모이드 함수의 특성은 예측값(y)이 항상 0 아니면 1 이다.

# %%
loss = -tf.reduce_mean(np.array(yData) * tf.log(y) + (1 - np.array(yData)) * tf.log(1 - y))

# %% [markdown]
# 오차를 최소로 하는 값을 찾는다.

# %%
gradient_descent = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

# %% [markdown]
# 학습 시킨다.

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

for i in range(300001):
    sess.run(gradient_descent)
    if i % 5000 == 0:
        # 학습 횟수(Epoch), 오차, 기울기, y절편
        print('Epoch: {0:6d}, loss: {1:8.4f}, 기울기: {2:8.4f}, y절편: {3:8.4f}'.format(i, sess.run(loss), sess.run(a)[0],
                                                                                  sess.run(b)[0]))
# Out:
# Epoch:      0, loss:   1.0445, 기울기:  -0.1572, y절편:   0.9431
# Epoch:   5000, loss:   0.0585, 기울기:   1.5525, y절편: -10.6788
# Epoch:  10000, loss:   0.0372, 기울기:   2.0063, y절편: -13.8778
# Epoch:  15000, loss:   0.0275, 기울기:   2.3156, y절편: -16.0509
# Epoch:  20000, loss:   0.0218, 기울기:   2.5529, y절편: -17.7161
# Epoch:  25000, loss:   0.0180, 기울기:   2.7457, y절편: -19.0689
# Epoch:  30000, loss:   0.0154, 기울기:   2.9083, y절편: -20.2087
# Epoch:  35000, loss:   0.0134, 기울기:   3.0488, y절편: -21.1933
# Epoch:  40000, loss:   0.0119, 기울기:   3.1725, y절편: -22.0598
# Epoch:  45000, loss:   0.0106, 기울기:   3.2829, y절편: -22.8333
# Epoch:  50000, loss:   0.0097, 기울기:   3.3826, y절편: -23.5318
# Epoch:  55000, loss:   0.0088, 기울기:   3.4734, y절편: -24.1684
# Epoch:  60000, loss:   0.0081, 기울기:   3.5569, y절편: -24.7531
# Epoch:  65000, loss:   0.0075, 기울기:   3.6341, y절편: -25.2937
# Epoch:  70000, loss:   0.0070, 기울기:   3.7058, y절편: -25.7963
# Epoch:  75000, loss:   0.0066, 기울기:   3.7729, y절편: -26.2659
# Epoch:  80000, loss:   0.0062, 기울기:   3.8358, y절편: -26.7065
# Epoch:  85000, loss:   0.0058, 기울기:   3.8951, y절편: -27.1215
# Epoch:  90000, loss:   0.0055, 기울기:   3.9511, y절편: -27.5137
# Epoch:  95000, loss:   0.0052, 기울기:   4.0041, y절편: -27.8853
# Epoch: 100000, loss:   0.0050, 기울기:   4.0546, y절편: -28.2386
# Epoch: 105000, loss:   0.0047, 기울기:   4.1026, y절편: -28.5751
# Epoch: 110000, loss:   0.0045, 기울기:   4.1485, y절편: -28.8964
# Epoch: 115000, loss:   0.0043, 기울기:   4.1924, y절편: -29.2038
# Epoch: 120000, loss:   0.0042, 기울기:   4.2345, y절편: -29.4984
# Epoch: 125000, loss:   0.0040, 기울기:   4.2749, y절편: -29.7813
# Epoch: 130000, loss:   0.0038, 기울기:   4.3137, y절편: -30.0533
# Epoch: 135000, loss:   0.0037, 기울기:   4.3512, y절편: -30.3153
# Epoch: 140000, loss:   0.0036, 기울기:   4.3872, y절편: -30.5679
# Epoch: 145000, loss:   0.0034, 기울기:   4.4221, y절편: -30.8118
# Epoch: 150000, loss:   0.0033, 기울기:   4.4557, y절편: -31.0476
# Epoch: 155000, loss:   0.0032, 기울기:   4.4883, y절편: -31.2758
# Epoch: 160000, loss:   0.0031, 기울기:   4.5199, y절편: -31.4969
# Epoch: 165000, loss:   0.0030, 기울기:   4.5505, y절편: -31.7113
# Epoch: 170000, loss:   0.0029, 기울기:   4.5803, y절편: -31.9193
# Epoch: 175000, loss:   0.0029, 기울기:   4.6091, y절편: -32.1215
# Epoch: 180000, loss:   0.0028, 기울기:   4.6372, y절편: -32.3180
# Epoch: 185000, loss:   0.0027, 기울기:   4.6645, y절편: -32.5091
# Epoch: 190000, loss:   0.0026, 기울기:   4.6911, y절편: -32.6953
# Epoch: 195000, loss:   0.0026, 기울기:   4.7170, y절편: -32.8766
# Epoch: 200000, loss:   0.0025, 기울기:   4.7422, y절편: -33.0535
# Epoch: 205000, loss:   0.0024, 기울기:   4.7669, y절편: -33.2259
# Epoch: 210000, loss:   0.0024, 기울기:   4.7909, y절편: -33.3943
# Epoch: 215000, loss:   0.0023, 기울기:   4.8144, y절편: -33.5588
# Epoch: 220000, loss:   0.0023, 기울기:   4.8374, y절편: -33.7195
# Epoch: 225000, loss:   0.0022, 기울기:   4.8598, y절편: -33.8766
# Epoch: 230000, loss:   0.0022, 기울기:   4.8818, y절편: -34.0303
# Epoch: 235000, loss:   0.0021, 기울기:   4.9033, y절편: -34.1808
# Epoch: 240000, loss:   0.0021, 기울기:   4.9243, y절편: -34.3281
# Epoch: 245000, loss:   0.0020, 기울기:   4.9449, y절편: -34.4723
# Epoch: 250000, loss:   0.0020, 기울기:   4.9651, y절편: -34.6137
# Epoch: 255000, loss:   0.0020, 기울기:   4.9849, y절편: -34.7523
# Epoch: 260000, loss:   0.0019, 기울기:   5.0043, y절편: -34.8882
# Epoch: 265000, loss:   0.0019, 기울기:   5.0233, y절편: -35.0216
# Epoch: 270000, loss:   0.0019, 기울기:   5.0420, y절편: -35.1525
# Epoch: 275000, loss:   0.0018, 기울기:   5.0604, y절편: -35.2809
# Epoch: 280000, loss:   0.0018, 기울기:   5.0784, y절편: -35.4071
# Epoch: 285000, loss:   0.0018, 기울기:   5.0961, y절편: -35.5311
# Epoch: 290000, loss:   0.0017, 기울기:   5.1135, y절편: -35.6529
# Epoch: 295000, loss:   0.0017, 기울기:   5.1306, y절편: -35.7727
# Epoch: 300000, loss:   0.0017, 기울기:   5.1475, y절편: -35.8904
